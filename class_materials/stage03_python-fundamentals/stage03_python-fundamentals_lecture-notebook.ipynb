# %% [markdown]
# # Stage 03: Python Fundamentals
#
# **Date:** Aug 14 (Thursday) (C)
#
# In this notebook, we explore core Python data structures, NumPy, pandas, and reusable functions.

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime

# %%
# %pip install pandas
# Out:
# Collecting pandas
#   Downloading pandas-3.0.5-cp312-cp312-macosx_11_0_arm64.whl.metadata (79 kB)
# Requirement already satisfied: numpy>=1.26.0 in /opt/anaconda3/envs/myenv/lib/python3.12/site-packages (from pandas) (2.5.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/anaconda3/envs/myenv/lib/python3.12/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/envs/myenv/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Downloading pandas-3.0.5-cp312-cp312-macosx_11_0_arm64.whl (10.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.0/10.0 MB 44.0 MB/s  0:00:00eta 0:00:01
# Installing collected packages: pandas
# Successfully installed pandas-3.0.5
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Warm-Up: Function and Decorator

# %%
def calc_mean_std(lst):
    arr = np.array(lst)
    return arr.mean(), arr.std()

# %%
temp = (1,2,3)
print(*temp)
print(1,2,3)
# Out:
# 1 2 3
# 1 2 3

# %% [markdown]
# #know how *args work

# %%
def my_func(y,*arg):
    print(arg)
    # for i in arg:
        # print(i)
my_func(1,2,3,'a')
# Out:
# (2, 3, 'a')

# %%
my_stock = {"stock":'appl',"quantity":500, "price":150}
my_stock2 = {"bond":'bootcamp',"expiry":'2026-01-01', "min":10000}
# print(list(my_stock.keys()))
# print(list(my_stock.values()))
# print(my_stock2)
{**my_stock  ,  **my_stock2 }
# Out:
# {'stock': 'appl',
#  'quantity': 500,
#  'price': 150,
#  'bond': 'bootcamp',
#  'expiry': '2026-01-01',
#  'min': 10000}

# %%
[my_stock[i] for i in my_stock]
# Out:
# ['appl', 500, 150]

# %%
def my_func(**args):
    print(args)
# my_func('appl',500, 150)
inputs = {'stock': 'appl', 'quantity': 500, 'price': 150,'fourth':444}
my_func(**inputs) #unwrap dic
# my_func(stock='appl',quantity=500, price=150)
# Out:
# {'stock': 'appl', 'quantity': 500, 'price': 150, 'fourth': 444}

# %%
def my_debug(f):
    def new_func(*arg):
        print("arg length: "+str(len(arg)))
        f(*arg)
        # print(arg)
    return new_func
    
# a_func = my_debug( my_func )
# a_func(1,2,3)

@my_debug #how this work?
def my_func(*args):
    print(args)

my_func(1,2,3)
# Out:
# arg length: 3
# (1, 2, 3)

# %%
def log_call(func):
    def wrapper(*args, **kwargs):
        print(f"Function {func.__name__} called at {datetime.now()}")
        return func(*args, **kwargs)
    return wrapper

# %%
@log_call
def calc_mean_std_logged(lst):
    return calc_mean_std(lst)

# %%
calc_mean_std_logged([1, 2, 3, 4, 5])
# Out:
# Function calc_mean_std_logged called at 2026-08-13 12:43:18.342077
# (np.float64(3.0), np.float64(1.4142135623730951))

# %% [markdown]
# ## Data Structures Comparison

# %%
lst = [1, 2, 3]
for i in lst:
    print(i)
[i*2 for i in lst]
arr = np.array(lst)
ser = pd.Series(lst)
df = pd.DataFrame({'col1': lst, 'col2': [4,5,6]})

print(type(lst), type(arr), type(ser), type(df))
# Out:
# 1
# 2
# 3
# <class 'list'> <class 'numpy.ndarray'> <class 'pandas.Series'> <class 'pandas.DataFrame'>

# %%
df
# Out:
#    col1  col2
# 0     1     4
# 1     2     5
# 2     3     6

# %% [markdown]
# ## Vectorization vs Loops

# %%
big_array = np.arange(1_000_000)

# %timeit [x * 2 for x in big_array]
# %timeit big_array * 2

# %% [markdown]
# ## Pandas Basics

# %%
df = pd.read_csv('data/raw/starter_data.csv')
df.head(), df.info(), df.describe()

# %% [markdown]
# ## Groupby & Aggregation

# %%
summary = df.groupby('category').mean(numeric_only=True).reset_index()
os.makedirs('data/processed', exist_ok=True)
summary.to_csv('data/processed/summary.csv', index=False)
summary

# %% [markdown]
# ## Plotting

# %%
df['value'].hist()
plt.savefig('data/processed/histogram.png')

# %%
from src.utils import get_summary_stats

# %%
get_summary_stats
